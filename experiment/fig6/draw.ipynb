# %%
teacher = [3, 64, 192, 128, 192, 128, 192, 128, 192, 128, 192, 128, 192, 128, 192, 128, 192, 128, 192, 128, 192, 128, 192, 128, 192, 128, 192, 128, 192, 128, 192, 128, 192, 128, 64, 3]
w_005 = [3, 15, 26, 41, 72, 58, 93, 67, 107, 72, 113, 74, 119, 75, 119, 75, 127, 75, 127, 75, 132, 75, 134, 75, 132, 75, 135, 75, 133, 74, 132, 74, 129, 75, 64, 3]
w_011 = [3, 11, 15, 22, 32, 32, 46, 43, 65, 52, 76, 58, 88, 61, 89, 64, 99, 65, 105, 66, 109, 67, 114, 67, 113, 67, 117, 66, 113, 66, 110, 66, 107, 67, 64, 3]
w_012 = [3, 10, 14, 20, 28, 29, 40, 39, 58, 48, 70, 55, 83, 59, 84, 62, 94, 63, 100, 65, 105, 65, 109, 65, 110, 65, 113, 65, 109, 65, 106, 65, 103, 66, 64, 3]
w_013 = [3, 9, 12, 18, 25, 25, 36, 34, 50, 44, 62, 51, 75, 55, 77, 58, 85, 61, 92, 62, 96, 63, 103, 64, 103, 64, 104, 64, 102, 64, 100, 64, 96, 64, 64, 3]
w_014 = [3, 9, 11, 17, 22, 23, 31, 31, 46, 41, 59, 49, 73, 53, 75, 57, 84, 59, 92, 61, 96, 62, 102, 62, 102, 63, 106, 63, 102, 63, 99, 63, 96, 63, 64, 3]
w_015 = [3, 8, 10, 15, 20, 21, 28, 28, 41, 38, 53, 46, 68, 50, 71, 54, 80, 57, 87, 59, 92, 60, 98, 61, 98, 61, 103, 61, 98, 62, 96, 62, 92, 62, 64, 3]
plot_x = [i+1 for i in range(len(w_011))]

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
font = {'family': 'Times New Roman', 'weight': 'normal', 'size': 18}
matplotlib.rc("font", **font)
plt.plot(plot_x, teacher, label='Teacher')
plt.plot(plot_x, w_005, label='θ = 0.05')
plt.plot(plot_x, w_011, label='θ = 0.11')
plt.plot(plot_x, w_012, label='θ=0.12')
plt.plot(plot_x, w_013, label='θ=0.13')
plt.plot(plot_x, w_014, label='θ=0.14')
plt.plot(plot_x, w_015, label='θ=0.15')
plt.legend(loc='best', bbox_to_anchor=(1, 1))
# plt.savefig('val_psnr'+".svg", dpi=1000, bbox_inches='tight')
plt.show()
