# %%
import sys, os
sys.path = ['/home/kailu/EDSR-PyTorch/code'] + sys.path
os.environ['LOCAL_BACKEND'] = '1'

# %% [markdown]
# ## Prepare Model

# %%
from frameworks.distillation.DEIP import load_model as deip_load
from pytorch_lightning import seed_everything
seed_everything(236)
plain_x = deip_load({'load_from': '/data/tmp/plainx_x4_236.ckpt'})
# Out:
# Global seed set to 236
# dataset_params: {'batch_size': 16, 'total_batch_size': 16, 'workers': 4, 'ext': 'sep', 'name': 'DIV2K', 'patch_size': 192, 'repeat': 20, 'scale': 4, 'test_bz': 1, 'dataset_mapping': (0, 1, 2), 'dataset_transforms': (0, 1, 1)}
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# len(dataset): 16000
# len(dataset): 10
# len(dataset): 10
# dataset_params: {'batch_size': 4, 'total_batch_size': 16, 'workers': 4, 'name': 'DIV2K', 'scale': 4, 'patch_size': 192, 'ext': 'sep', 'repeat': 20, 'test_bz': 1, 'dataset_mapping': (0, 1, 2), 'dataset_transforms': (0, 1, 1)}
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# len(dataset): 16000
# len(dataset): 10
# len(dataset): 10
# ...

# %%
from frameworks.distillation.DEIP import load_model as deip_load
from pytorch_lightning import seed_everything
seed_everything(236)
plain_m = deip_load({'load_from': '/data/tmp/plainmx4_236.ckpt'})
# Out:
# Global seed set to 236
# dataset_params: {'batch_size': 16, 'total_batch_size': 16, 'workers': 4, 'ext': 'sep', 'name': 'DIV2K', 'patch_size': 192, 'repeat': 20, 'scale': 4, 'test_bz': 1, 'dataset_mapping': (0, 1, 2), 'dataset_transforms': (0, 1, 1)}
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# len(dataset): 16000
# len(dataset): 10
# len(dataset): 10
# /home/kailu/miniconda3/envs/wukailu/lib/python3.7/site-packages/torchmetrics/utilities/prints.py:37: UserWarning: Metric `SSIM` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# dataset_params: {'batch_size': 4, 'total_batch_size': 16, 'workers': 4, 'name': 'DIV2K', 'scale': 4, 'patch_size': 192, 'ext': 'sep', 'repeat': 20, 'test_bz': 1, 'dataset_mapping': (0, 1, 2), 'dataset_transforms': (0, 1, 1)}
# ...

# %%
from frameworks.superresolution.SRModel import load_model as sr_load
from frameworks.superresolution.jobs_for_sr import templates
params = {
    'backbone': {
        'arch': 'imdn_sr',
        'scale': 4,
    },
    'init_from': '/data/tmp/imdnx4_235.ckpt',
}
imdn = sr_load({**templates['DIV2Kx4-EXP'], **params})
# Out:
# Preparing loss function:
# 1.000 * L1
# dataset_params: {'batch_size': 128, 'total_batch_size': 16, 'name': 'DIV2K', 'scale': 4, 'patch_size': 192, 'ext': 'sep', 'repeat': 20, 'test_bz': 1, 'dataset_mapping': (0, 1, 2), 'dataset_transforms': (0, 1, 1)}
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# len(dataset): 16000
# len(dataset): 10
# len(dataset): 10
# pretrain from  /data/tmp/imdnx4_235.ckpt  loaded
# Preparing loss function:
# 1.000 * L1
# dataset_params: {'batch_size': 16, 'total_batch_size': 16, 'workers': 4, 'name': 'DIV2K', 'scale': 4, 'patch_size': 192, 'ext': 'sep', 'repeat': 20, 'test_bz': 1, 'dataset_mapping': (0, 1, 2), 'dataset_transforms': (0, 1, 1)}
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# len(dataset): 16000
# ...

# %%
from frameworks.superresolution.SRModel import load_model as sr_load
from frameworks.superresolution.jobs_for_sr import templates
params = {
    'backbone': {
        'arch': 'edsr_sr',
        'scale': 4,
    },
    'init_from': '/data/tmp/edsrx4_234.ckpt',
}
edsr = sr_load({**templates['DIV2Kx4-EXP'], **params})
# Out:
# Preparing loss function:
# 1.000 * L1
# dataset_params: {'batch_size': 128, 'total_batch_size': 16, 'name': 'DIV2K', 'scale': 4, 'patch_size': 192, 'ext': 'sep', 'repeat': 20, 'test_bz': 1, 'dataset_mapping': (0, 1, 2), 'dataset_transforms': (0, 1, 1)}
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# len(dataset): 16000
# len(dataset): 10
# len(dataset): 10
# pretrain from  /data/tmp/edsrx4_234.ckpt  loaded
# Preparing loss function:
# 1.000 * L1
# dataset_params: {'batch_size': 16, 'total_batch_size': 16, 'workers': 4, 'name': 'DIV2K', 'scale': 4, 'patch_size': 192, 'ext': 'sep', 'repeat': 20, 'test_bz': 1, 'dataset_mapping': (0, 1, 2), 'dataset_transforms': (0, 1, 1)}
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# len(dataset): 16000
# ...

# %%
from frameworks.superresolution.SRModel import load_model as sr_load
from frameworks.superresolution.jobs_for_sr import templates
params = {
    'backbone': {
        'arch': 'bicubic_sr',
        'scale': 4,
    },
}
bib = sr_load({**templates['DIV2Kx4-EXP'], **params})
# Out:
# Preparing loss function:
# 1.000 * L1
# dataset_params: {'batch_size': 128, 'total_batch_size': 16, 'name': 'DIV2K', 'scale': 4, 'patch_size': 192, 'ext': 'sep', 'repeat': 20, 'test_bz': 1, 'dataset_mapping': (0, 1, 2), 'dataset_transforms': (0, 1, 1)}
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# len(dataset): 16000
# len(dataset): 10
# len(dataset): 10

# %%
import torch
from frameworks.superresolution.SRModel import load_model as sr_load
from frameworks.superresolution.jobs_for_sr import templates
params = {
    'backbone': {
        'arch': 'carn_sr',
        'scale': 4,
        'multi_scale': True,
        'rgb_range': 255,
    },
}
carn = sr_load({**templates['DIV2Kx4-EXP'], **params})
carn.model.load_state_dict(torch.load('/data/tmp/carn.pth'))
# Out:
# Preparing loss function:
# 1.000 * L1
# dataset_params: {'batch_size': 128, 'total_batch_size': 16, 'name': 'DIV2K', 'scale': 4, 'patch_size': 192, 'ext': 'sep', 'repeat': 20, 'test_bz': 1, 'dataset_mapping': (0, 1, 2), 'dataset_transforms': (0, 1, 1)}
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# len(dataset): 16000
# len(dataset): 10
# len(dataset): 10
# <All keys matched successfully>

# %%
from frameworks.superresolution.SRModel import load_model as sr_load
from frameworks.superresolution.jobs_for_sr import templates
params = {
    'backbone': {
        'arch': 'fsrcnn_sr',
        'scale': 4,
    },
    'init_from': '/data/tmp/fsrcnnx4_233.ckpt',
}
fsrcnn = sr_load({**templates['DIV2Kx4-EXP'], **params})
# Out:
# Preparing loss function:
# 1.000 * L1
# dataset_params: {'batch_size': 128, 'total_batch_size': 16, 'name': 'DIV2K', 'scale': 4, 'patch_size': 192, 'ext': 'sep', 'repeat': 20, 'test_bz': 1, 'dataset_mapping': (0, 1, 2), 'dataset_transforms': (0, 1, 1)}
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# len(dataset): 16000
# len(dataset): 10
# len(dataset): 10
# pretrain from  /data/tmp/fsrcnnx4_233.ckpt  loaded
# Preparing loss function:
# 1.000 * L1
# dataset_params: {'batch_size': 16, 'total_batch_size': 16, 'workers': 4, 'name': 'DIV2K', 'scale': 4, 'patch_size': 192, 'ext': 'sep', 'repeat': 20, 'test_bz': 1, 'dataset_mapping': (0, 1, 2), 'dataset_transforms': (0, 1, 1)}
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# len(dataset): 16000
# ...

# %%
from frameworks.superresolution.SRModel import load_model as sr_load
from frameworks.superresolution.jobs_for_sr import templates
params = {
    'backbone': {
        'arch': 'srcnn_sr',
        'scale': 4,
    },
    'init_from': '/data/tmp/srcnnx4_233.ckpt',
}
srcnn = sr_load({**templates['DIV2Kx4-EXP'], **params})
# Out:
# Preparing loss function:
# 1.000 * L1
# dataset_params: {'batch_size': 128, 'total_batch_size': 16, 'name': 'DIV2K', 'scale': 4, 'patch_size': 192, 'ext': 'sep', 'repeat': 20, 'test_bz': 1, 'dataset_mapping': (0, 1, 2), 'dataset_transforms': (0, 1, 1)}
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# len(dataset): 16000
# len(dataset): 10
# len(dataset): 10
# pretrain from  /data/tmp/srcnnx4_233.ckpt  loaded
# Preparing loss function:
# 1.000 * L1
# dataset_params: {'batch_size': 16, 'total_batch_size': 16, 'workers': 4, 'name': 'DIV2K', 'scale': 4, 'patch_size': 192, 'ext': 'sep', 'repeat': 20, 'test_bz': 1, 'dataset_mapping': (0, 1, 2), 'dataset_transforms': (0, 1, 1)}
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# len(dataset): 16000
# ...

# %%
from frameworks.superresolution.SRModel import load_model as sr_load
from frameworks.superresolution.jobs_for_sr import templates
params = {
    'backbone': {
        'arch': 'vdsr_sr',
        'scale': 4,
    },
    'init_from': '/data/tmp/vdsrx4_233.ckpt',
}
vdsr = sr_load({**templates['DIV2Kx4-EXP'], **params})
# Out:
# Preparing loss function:
# 1.000 * L1
# dataset_params: {'batch_size': 128, 'total_batch_size': 16, 'name': 'DIV2K', 'scale': 4, 'patch_size': 192, 'ext': 'sep', 'repeat': 20, 'test_bz': 1, 'dataset_mapping': (0, 1, 2), 'dataset_transforms': (0, 1, 1)}
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# len(dataset): 16000
# len(dataset): 10
# len(dataset): 10
# pretrain from  /data/tmp/vdsrx4_233.ckpt  loaded
# Preparing loss function:
# 1.000 * L1
# dataset_params: {'batch_size': 16, 'total_batch_size': 16, 'workers': 4, 'name': 'DIV2K', 'scale': 4, 'patch_size': 192, 'ext': 'sep', 'repeat': 20, 'test_bz': 1, 'dataset_mapping': (0, 1, 2), 'dataset_transforms': (0, 1, 1)}
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# len(dataset): 16000
# ...

# %%
from frameworks.lightning_base_model import _Module
teacher = _Module.load_from_checkpoint(checkpoint_path='/data/pretrained/lightning_models/layerwise_edsrx4_div2k_69068.ckpt').model
# Out:
# dataset_params: {'batch_size': 4, 'total_batch_size': 16, 'workers': 4, 'name': 'DIV2K', 'scale': 4, 'patch_size': 192, 'ext': 'sep', 'repeat': 20, 'test_bz': 1, 'dataset_mapping': (0, 1, 2), 'dataset_transforms': (0, 1, 1)}
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# Preprocessing high resolution sr data...
# Preprocessing low resolution sr data...
# len(dataset): 16000
# len(dataset): 10
# len(dataset): 10

# %% [markdown]
# ## Main

# %%
def RGB_to_gray(preds):
    gray_coeffs = [65.738, 129.057, 25.064]
    convert = preds.new_tensor(gray_coeffs).view(1, 3, 1, 1) / 256
    return preds.mul(convert).sum(dim=1)

# %%
def view(data, do_sum=False, save_to=None):
    import matplotlib.pyplot as plt
    # %matplotlib inline
    if do_sum:
        plt.imshow(data.squeeze().permute(1,2,0).sum(dim=2).numpy()/255)
    else:
        plt.imshow(data.squeeze().permute(1,2,0).numpy()/255)
    plt.show()
    if save_to is not None:
        from PIL import Image
        ndarr = data.squeeze().clamp(0, 255).permute(1,2,0).byte().numpy()
        im = Image.fromarray(ndarr)
        im.save(save_to)

from datasets import DataProvider
dataset_params = {
    'name': 'Urban100',
#     'name': 'B100',
#     'name': 'Set14',
    'test_only': True,
    'patch_size': 192,
    'ext': 'sep',
    'scale': 4,
    "batch_size": 1,
}
provider = DataProvider(dataset_params)
# Out:
# dataset_params: {'name': 'Urban100', 'test_only': True, 'patch_size': 192, 'ext': 'sep', 'scale': 4, 'batch_size': 1, 'dataset_mapping': (0, 1, 2), 'dataset_transforms': (0, 1, 1)}
# len(dataset): 100
# len(dataset): 100
# len(dataset): 100

# %%
name = ('plain_x', 'plain_m', 'imdn', 'edsr', 'bib', 'carn')
methods = (plain_x, plain_m, imdn, edsr, bib, carn)
coe = (1, 0, -1, -1, 0, -1)
# coe = (1, 1, -1, -1, 0, -1)

import torch
pool = torch.nn.MaxPool2d(60, stride=30)

best_lr = None
best_hr = None
best_score = -1e9
best_mp = None
with torch.no_grad():
    for idx, batch in enumerate(provider.test_dl):
        x, y, _ = batch
        x = x.cuda()
        gray_y = RGB_to_gray(y).cuda()
        mp = 0
        d = {1:[], -1:[], 0:[]}
        for m, c in zip(methods, coe):
            m = m.cuda()
            p = RGB_to_gray(m(x))
#             diff = pool((gray_y-p).abs())
            diff = (gray_y-p).abs()
            d[c].append(diff)
        for k in d:
            if k == 1:
                mp += torch.min(torch.stack(d[k], dim=0), dim=0).values * k
            elif k== -1:
                mp += torch.mean(torch.stack(d[k], dim=0), dim=0) * k
        mp = mp.cpu()
        score = mp.max()
        if score > best_score and idx not in [10]:
            best_score = score
            best_hr = y.cpu()
            best_lr = x.cpu()
            best_mp = mp[0]
            print('update with img_id = ', idx, 'score = ', score, 'filename = ', _)
# Out:
# update with img_id =  0 score =  tensor(34.7586) filename =  ['img001']
# update with img_id =  1 score =  tensor(50.0181) filename =  ['img002']
# update with img_id =  3 score =  tensor(72.9635) filename =  ['img004']
# update with img_id =  18 score =  tensor(76.4854) filename =  ['img019']
# update with img_id =  19 score =  tensor(79.8542) filename =  ['img020']
# update with img_id =  23 score =  tensor(119.6260) filename =  ['img024']
# update with img_id =  66 score =  tensor(138.9688) filename =  ['img067']

# %%
ks = 1
# window_size = (40, 80)
window_size = (30, 60)
width = best_mp.size(1)
pos = best_mp.view((-1,)).argmax(0).item()
pos_r, pos_c = pos//width, pos%width
pos_r, pos_c = pos_r*ks, pos_c*ks
print(pos_r, pos_c)
selects = ( 0,
            slice(0, None),
            slice(max(0, pos_r-window_size[0]), min(best_mp.size(0)*ks, pos_r+window_size[0])),
            slice(max(0, pos_c-window_size[1]), min(best_mp.size(1)*ks, pos_c+window_size[1])),)
view(best_hr), selects
# Out:
# 127 616
# (None, (0, slice(0, None, None), slice(97, 157, None), slice(556, 676, None)))

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image

plt.rcParams['figure.figsize'] = [16, 8]

ndarr = best_lr.squeeze().clamp(0, 255).permute(1,2,0).byte().numpy()
im = Image.fromarray(ndarr)

# Create figure and axes
fig, ax = plt.subplots()
# Display the image
ax.imshow(im)
# Create a Rectangle patch
rect = patches.Rectangle(((pos_c - window_size[1])//4, (pos_r - window_size[0])//4), window_size[1]//2, window_size[0]//2, 
                         linewidth=3, edgecolor='r', facecolor='none')
# Add the patch to the Axes
ax.add_patch(rect)
plt.axis('off')
plt.savefig('lr.png', bbox_inches='tight', dpi=1000)
plt.show()

# %%
print('hr')
view(best_hr[selects], save_to='ex_hr.png')
with torch.no_grad():
    for m, n in zip(methods, name):
        m = m.cuda()
        out = m(best_lr.cuda())
        print(n)
        view(out.cpu()[selects], save_to=f'ex_{n}.png')
# Out:
# hr
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# plain_x
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# plain_m
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# imdn
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# edsr
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# bib
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# carn

# %%
extra_names = ('fsrcnn', 'srcnn', 'vdsr', 'teacher')
extra_methods = (fsrcnn, srcnn, vdsr, teacher)

with torch.no_grad():
    for m, n in zip(extra_methods, extra_names):
        m = m.cuda()
        out = m(best_lr.cuda())
        print(n)
        view(out.cpu()[selects], save_to=f'ex_{n}.png')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# fsrcnn
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# srcnn
# vdsr
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# teacher
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
